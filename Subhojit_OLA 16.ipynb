# %% [markdown]
# **Step 1:**
# - Sign in to the GMail ID that you have enrolled in the training program with.
#     - You will have to enter your password.
#     - You might also be asked to verify the login on your phone/other device."
#
# **Step 2:**
# - After signing in, make a copy of the question sheet.
# - Rename this copy to "Your_Name_OLA-16"
# - Start your work."
#
# **Note:** Do not close the sheet you are working on. It cannot be opened again and you will have to start from the beginning.
#
# **Step 3:**
#
# 1) Read the case and complete the task listed below:
#
# SmartChoice is a well-known company that makes tablets, smartphones, and phablets. In 2024, after launching new models in different regions, the management set ambitious sales targets for each type of product. To help grow the business, they established specific sales goals for each region and month.

# %% [markdown]
# **Task 1**
#
#
#
# Set Up Colab environment for Python
# Import Pandas and matplotlib.pyplot libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Task 2**
#
# Print the first 5 rows of the Data Frame named "Budget” from the given URL.
#
# Budget: https://raw.githubusercontent.com/Invact-Abhay/DOE11/refs/heads/main/SmartChoice%20-%20Budget.csv

# %%
Budget=pd.read_csv("https://raw.githubusercontent.com/Invact-Abhay/DOE11/refs/heads/main/SmartChoice%20-%20Budget.csv")
Budget.head()
# Out:
#      Month Region Factory Code       Model  Budgeted Quantity
# 0  January  North        F001N      Tablet               1028
# 1  January  North        F001N  Smartphone                290
# 2  January  North        F001N     Phablet                331
# 3  January  North        F002N      Tablet               1474
# 4  January  North        F002N  Smartphone                459

# %% [markdown]
# **Task 3**
#
# Print the first five rows of the DataFrame named "Actual" using the provided URL.
#
# Actual: https://raw.githubusercontent.com/Invact-Abhay/DOE11/refs/heads/main/SmartChoice%20-%20Actual.csv

# %%
Actual=pd.read_csv("https://raw.githubusercontent.com/Invact-Abhay/DOE11/refs/heads/main/SmartChoice%20-%20Actual.csv")
Actual.head()
# Out:
#         Date    Month Region Factory Code       Model  \
# 0  1/30/2024  January  North        F002N      Tablet
# 1  1/27/2024  January  South        F003S  Smartphone
# 2  1/21/2024  January   West        F003W     Phablet
# 3   1/2/2024  January  North        F002N      Tablet
# 4  1/23/2024  January  South        F001S  Smartphone
#
#    Actual Quantity Produced
# 0                        41
# 1                        34
# 2                        17
# 3                        26
# 4                        90

# %% [markdown]
# **Task 4**
#
# Convert all column names in the Actual and Budget DataFrame to lowercase and replace spaces with underscores.

# %%
Budget.columns=Budget.columns.str.lower().str.replace(" ","_")
Actual.columns=Actual.columns.str.lower().str.replace(" ","_")

# %%
Budget.columns
# Out:
# Index(['month', 'region', 'factory_code', 'model', 'budgeted_quantity'], dtype='object')

# %%
Actual.columns
# Out:
# Index(['date', 'month', 'region', 'factory_code', 'model',
#        'actual_quantity_produced'],
#       dtype='object')

# %% [markdown]
# **Task 5**
#
# Group the Actual Data Frame by month, region, factory-code, and model, then sum the actual production column and create a new Data Frame with the result stored in a column named actual. Your output should contain following columns month,region, factory_code, model and actual production

# %%
actual=Actual.groupby(['month','region','factory_code','model'])['actual_quantity_produced'].sum().reset_index()
actual
# Out:
#          month region factory_code       model  actual_quantity_produced
# 0        April  North        F001N     Phablet                      1180
# 1        April  North        F001N  Smartphone                       116
# 2        April  North        F001N      Tablet                        62
# 3        April  North        F002N     Phablet                      1299
# 4        April  North        F002N  Smartphone                       123
# ..         ...    ...          ...         ...                       ...
# 314  September   West        F002W     Phablet                       314
# 315  September   West        F002W  Smartphone                       827
# 316  September   West        F002W      Tablet                       323
# 317  September   West        F003W     Phablet                       377
# 318  September   West        F003W  Smartphone                      1047
#
# [319 rows x 5 columns]

# %% [markdown]
# **Task 6**
#
# Merge the Budget DataFrame with the Grouped_Actual DataFrame, based on the month, region, factory-code and model columns. Your Output should include the following columns month, region, factory_code, model and actual _production.

# %%
merged_table=pd.merge(Budget,actual, on=['month','region','factory_code','model'],how='left')
merged_table
# Out:
#         month region factory_code       model  budgeted_quantity  \
# 0     January  North        F001N      Tablet               1028
# 1     January  North        F001N  Smartphone                290
# 2     January  North        F001N     Phablet                331
# 3     January  North        F002N      Tablet               1474
# 4     January  North        F002N  Smartphone                459
# ..        ...    ...          ...         ...                ...
# 319  December   West        F002W  Smartphone                805
# 320  December   West        F002W     Phablet                171
# 321  December   West        F003W      Tablet                144
# 322  December   West        F003W  Smartphone                559
# 323  December   West        F003W     Phablet                434
#
#      actual_quantity_produced
# 0                       869.0
# 1                       275.0
# 2                       284.0
# 3                      1185.0
# ...

# %% [markdown]
# **Task 7**
#
# Calculate the variance between actual production and budgeted_quantity for each row in the merged_table DataFrame and store the result in a new column called variance. Your Output should include the following columns month, region, factory_code, model, actual _production and variance.

# %%
merged_table['variance']=merged_table['actual_quantity_produced']-merged_table['budgeted_quantity']
merged_table
# Out:
#         month region factory_code       model  budgeted_quantity  \
# 0     January  North        F001N      Tablet               1028
# 1     January  North        F001N  Smartphone                290
# 2     January  North        F001N     Phablet                331
# 3     January  North        F002N      Tablet               1474
# 4     January  North        F002N  Smartphone                459
# ..        ...    ...          ...         ...                ...
# 319  December   West        F002W  Smartphone                805
# 320  December   West        F002W     Phablet                171
# 321  December   West        F003W      Tablet                144
# 322  December   West        F003W  Smartphone                559
# 323  December   West        F003W     Phablet                434
#
#      actual_quantity_produced  variance
# 0                       869.0    -159.0
# 1                       275.0     -15.0
# 2                       284.0     -47.0
# ...

# %% [markdown]
# **Task 8**
#
# Create a new column month_number in the merged_table DataFrame by mapping the month names to their corresponding numerical values using a dictionary, and then display the first few rows of the updated DataFrame. Your Output should include the following columns month, region, factory_code, model, actual _production, variance and month_number.

# %%
month_mapping={'January':1,
               'February':2,
               'March':3,
               'April':4,
               'May':5,
               'June':6,
               'July':7,
               'August':8,
               'September':9,
               'October':10,
               'November':11,
               'December':12 }
merged_table['month_number']=merged_table['month'].map(month_mapping)
merged_table
# Out:
#         month region factory_code       model  budgeted_quantity  \
# 0     January  North        F001N      Tablet               1028
# 1     January  North        F001N  Smartphone                290
# 2     January  North        F001N     Phablet                331
# 3     January  North        F002N      Tablet               1474
# 4     January  North        F002N  Smartphone                459
# ..        ...    ...          ...         ...                ...
# 319  December   West        F002W  Smartphone                805
# 320  December   West        F002W     Phablet                171
# 321  December   West        F003W      Tablet                144
# 322  December   West        F003W  Smartphone                559
# 323  December   West        F003W     Phablet                434
#
#      actual_quantity_produced  variance  month_number
# 0                       869.0    -159.0             1
# 1                       275.0     -15.0             1
# ...

# %% [markdown]
# **Task 9**
#
# Group the merged_table by month and month_number, sum the variance for each group and then sort the resulting monthly_merged_table by month_number in ascending order.  Your Output should include the following columns month, month number and variance.

# %%
monthly_merged_table=merged_table.groupby(['month','month_number'])['variance'].sum().reset_index().sort_values('month_number',ascending=True)
monthly_merged_table
# Out:
#         month  month_number  variance
# 4     January             1   -1945.0
# 3    February             2   -2252.0
# 7       March             3   -2135.0
# 0       April             4   -2160.0
# 8         May             5   -2073.0
# 6        June             6   -2180.0
# 5        July             7   -1917.0
# 1      August             8   -1330.0
# 11  September             9   -1747.0
# 10    October            10     347.0
# 9    November            11     875.0
# 2    December            12    1861.0

# %% [markdown]
# **Task 10**
#
# Create a bar chart using the monthly_merged DataFrame, where the month column is plotted on the x-axis and the variance column is plotted as the height of the bars, also label the axes and rotate the x-axis labels by 90 degrees. Name the Chart as "Monthly Variance".

# %%
plt.bar(x=monthly_merged_table['month'],height=monthly_merged_table['variance'])
plt.xlabel("Month")
plt.ylabel("Variance")
plt.xticks(ticks=monthly_merged_table['month'],rotation=90)
plt.title("Monthly Variance")
plt.show()

# %% [markdown]
# **Task 11**
#
# Create a region_wise_variance DataFrame that groups the merged_table by 'region' and calculates the sum of the 'variance' for each region, then resets the index. Your Output should include the following columns region and variance.

# %%
region_wise_variance=merged_table.groupby('region')['variance'].sum().reset_index()
region_wise_variance
# Out:
#   region  variance
# 0  North   -5965.0
# 1  South   -2793.0
# 2   West   -5898.0

# %% [markdown]
# **Task 12**
#
# Create a bar chart using the region_wise_variance DataFrame, where the 'region' column is plotted on the x-axis and the 'variance' column represents the height of the bars, while also labeling the axes appropriately. Name the chart as "Region-wise Variance".

# %%
plt.bar(x=region_wise_variance['region'],height=region_wise_variance['variance'])
plt.xlabel("Region")
plt.ylabel("Variance")
plt.title("Region-wise Variance")
plt.show()

# %% [markdown]
# **Task 13**
#
# DataFrame called model_wise_variance_table that summarizes the total variance of production quantity by model from the merged_table DataFrame, using the group by function to aggregate the 'variance' column.Your Output should include the following columns model and variance.

# %%
model_wise_variance=merged_table.groupby('model')['variance'].sum().reset_index()
model_wise_variance
# Out:
#         model  variance
# 0     Phablet   -4618.0
# 1  Smartphone   -5205.0
# 2      Tablet   -4833.0

# %% [markdown]
# **Task 14**
#
# Create a bar chart to visualize the model-wise variance using the model_wise_variance DataFrame, where the “model” names are on the x-axis and the “variance” values are represented as the height of the bars.
#
# Additionally, label the axes and rotate the x-axis labels by 90 degrees for better readability. Name the chart as " Model-wise Variance".

# %%
plt.bar(x=model_wise_variance['model'],height=model_wise_variance['variance'])
plt.xlabel("Model")
plt.ylabel('Variance')
plt.xticks(ticks=model_wise_variance['model'],rotation=90)
plt.title("Model-wise Variance")
plt.show()

# %% [markdown]
# **Step 4:**
#
# Once done, go to Share --> Restricted --> Access to Anyone with the Link --> Editor --> Copy the Link.

# %% [markdown]
# **Step 5:**
#
# Paste the link in the Google Form given below and submit within the deadline.
# Make sure you are ready to submit and have copied the Sheet Link with Editor access before opening the form.
#
# Form: https://forms.gle/CyTadKGANxygJ66R9
#
# When you click the form above, two messages will appear. Please select the first message.  ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 6:**
#
# You can close the exam by clicking the power button in the bottom-right corner.
#
# The password to quit is: invact@1
